# %%
import pandas as pd
import pathlib
from pathlib import PurePath, Path
import numpy as np
import os
from tqdm import tqdm

# %%
def has_parent_X(path: Path, X: str) -> bool:
    for parent in path.parents:
        if parent.name == X:
            return True
    return False

# %%
# Define the base directory
data_dir = Path('training_datasets')

# Create a list of .fits files in the directory and its subdirectories
file_list = data_dir.glob("**/**/**/*.fits")

# Initialize the DataFrame with the desired columns
df = pd.DataFrame(columns=["file_name", "classes"])

# Function to check if a file has a specific parent directory
def has_parent_X(path, parent_dir):
    return parent_dir in path.parts

# Iterate through the list of files
for fl in tqdm(file_list):
    # Remove the 'training_datasets/' prefix from the path
    relative_path = fl.relative_to(data_dir).as_posix()
    # Determine the class based on the parent directory
    if has_parent_X(fl, "dual_AGN_datasets") and has_parent_X(fl, "train_data") and not has_parent_X(fl, "HSC-I") and not has_parent_X(fl, "bad_train_data") and not has_parent_X(fl, "old_train_data") and not has_parent_X(fl, "new_train_data") and not has_parent_X(fl, "Rotated_AGN_diff_fltrs") and not has_parent_X(fl, "seeing_limited_train_data"):
        df.loc[len(df)] = {"file_name": relative_path, "classes": "dual_agn"}
    elif has_parent_X(fl, "single_AGN_datasets") and has_parent_X(fl, "confirmed_single_AGN") and not has_parent_X(fl, "HSC-I") and not has_parent_X(fl, "spring") and not has_parent_X(fl, "fall") and not has_parent_X(fl, "north") and not has_parent_X(fl, "1.59")  and not has_parent_X(fl, "HSC-G"):
        df.loc[len(df)] = {"file_name": relative_path, "classes": "single_agn"}
    elif has_parent_X(fl, "merger_datasets") and has_parent_X(fl, "new_train_data") and not has_parent_X(fl, "HSC-I") and not has_parent_X(fl, "new_train_data"):
        df.loc[len(df)] = {"file_name": relative_path, "classes": "merger"}
    elif has_parent_X(fl, "offset_AGN_datasets") and has_parent_X(fl, "train_data") and not has_parent_X(fl, "HSC-I") and not has_parent_X(fl, "old_train_data"):
        df.loc[len(df)] = {"file_name": relative_path, "classes": "offset_agn"}
    elif has_parent_X(fl, "empty_space_dataset") and has_parent_X(fl, "empty_space_train_data") and not has_parent_X(fl, "HSC-I") and not has_parent_X(fl, "downloader_files"):
        df.loc[len(df)] = {"file_name": relative_path, "classes": "empty_space"}
# Out:
# 461919it [01:55, 4014.80it/s]

# %%
df.to_csv("training_datasets/info.csv")
df
# Out:
#                                                file_name     classes
# 0      dual_AGN_datasets/train_data/object0_with_AGN_...    dual_agn
# 1      dual_AGN_datasets/train_data/object10002_with_...    dual_agn
# 2      dual_AGN_datasets/train_data/object10003_with_...    dual_agn
# 3      dual_AGN_datasets/train_data/object10008_with_...    dual_agn
# 4      dual_AGN_datasets/train_data/object10008_with_...    dual_agn
# ...                                                  ...         ...
# 75469  single_AGN_datasets/confirmed_single_AGN/UNK_1...  single_agn
# 75470  single_AGN_datasets/confirmed_single_AGN/UNK_1...  single_agn
# 75471  single_AGN_datasets/confirmed_single_AGN/UNK_1...  single_agn
# 75472  single_AGN_datasets/confirmed_single_AGN/UNK_1...  single_agn
# 75473  single_AGN_datasets/confirmed_single_AGN/UNK_1...  single_agn
#
# [75474 rows x 2 columns]

# %%
import pandas as pd
# Count the occurrences of each class
class_counts = df['classes'].value_counts()

# Find the minimum count
min_count = class_counts.min()
print(class_counts)

# Sample min_count instances from each class
balanced_df = df.groupby('classes').apply(lambda x: x.sample(min_count)).reset_index(drop=True)
remaining_df = df[~df["file_name"].isin(balanced_df["file_name"])]

print(balanced_df)
print(remaining_df)
# Out:
# classes
# dual_agn       33671
# offset_agn     29509
# empty_space     9336
# single_agn      2958
# Name: count, dtype: int64
#                                                file_name     classes
# 0      dual_AGN_datasets/train_data/object1730_with_A...    dual_agn
# 1      dual_AGN_datasets/train_data/object11260_with_...    dual_agn
# 2      dual_AGN_datasets/train_data/object28667_with_...    dual_agn
# 3      dual_AGN_datasets/train_data/object12246_with_...    dual_agn
# 4      dual_AGN_datasets/train_data/object24722_with_...    dual_agn
# ...                                                  ...         ...
# 11827  single_AGN_datasets/confirmed_single_AGN/QSO_0...  single_agn
# 11828  single_AGN_datasets/confirmed_single_AGN/QSO_1...  single_agn
# 11829  single_AGN_datasets/confirmed_single_AGN/QSO_1...  single_agn
# 11830  single_AGN_datasets/confirmed_single_AGN/QSO_0...  single_agn
# 11831  single_AGN_datasets/confirmed_single_AGN/QSO_0...  single_agn
#
# [11832 rows x 2 columns]
#                                                file_name     classes
# 0      dual_AGN_datasets/train_data/object0_with_AGN_...    dual_agn
# 1      dual_AGN_datasets/train_data/object10002_with_...    dual_agn
# 2      dual_AGN_datasets/train_data/object10003_with_...    dual_agn
# 3      dual_AGN_datasets/train_data/object10008_with_...    dual_agn
# 4      dual_AGN_datasets/train_data/object10008_with_...    dual_agn
# ...                                                  ...         ...
# 72511  offset_AGN_datasets/train_data/object9_with_AG...  offset_agn
# 72512  offset_AGN_datasets/train_data/object9_with_AG...  offset_agn
# 72513  offset_AGN_datasets/train_data/object9_with_AG...  offset_agn
# 72514  offset_AGN_datasets/train_data/object9_with_AG...  offset_agn
# 72515  offset_AGN_datasets/train_data/object9_with_AG...  offset_agn
#
# [63642 rows x 2 columns]
# /tmp/ipykernel_3568321/3808196611.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_df = df.groupby('classes').apply(lambda x: x.sample(min_count)).reset_index(drop=True)

# %%
df.to_csv("training_datasets/info.csv")
